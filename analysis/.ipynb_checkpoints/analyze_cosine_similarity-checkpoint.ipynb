# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import ast # to convert strings to a list

# %% [markdown]
# ## Functions for Cleaning Data

# %%
def load_data(filename):
    return pd.read_csv(filename)

def str_to_list(str_list):
    try: 
        lst = ast.literal_eval(str_list)
    except ValueError as ve:
        # print(ve)
        lst = []
    return lst

def get_avg_sim(scores):
    try:
        avg = sum(scores)/len(scores)
    except ZeroDivisionError as zde:
        # print(f'Error: {zde}')
        avg = None
    return avg

def get_max_score(scores):
    try:
        max_score = max(scores)
    except ValueError as ve:
        # print(ve)
        max_score = None
    return max_score


def transform_df(df):
    # convert str columns to lists
    df['similarities_lst'] = df['similarities'].apply(str_to_list)
    df['cos_sim_scores_lst'] = df['cos_sim_scores'].apply(str_to_list)
    df['headlines_lst'] = df['nyt_headlines'].apply(str_to_list)
    
    # add columns 
    df['avg_sim'] = df['cos_sim_scores_lst'].apply(get_avg_sim)
    df['max_score'] = df['cos_sim_scores_lst'].apply(get_max_score)
    df['num_headlines'] = df['nyt_headlines'].apply(len)
    
    # remove na vals
    clean = df.dropna()
    
    # remove duplicate rows
    clean_no_dup = clean.drop_duplicates(subset=['video_id','date'])
    
    sorted_df = clean_no_dup.sort_values(by='max_score',ascending=False)
    
    return sorted_df

# %% [markdown]
# ## Exploring Data

# %%
def explore_data(df):
    unique_vids = df['video_id'].unique()
    print(f'Total Number of Rows: {len(df)}')
    print(f'Number of Unique Videos: {len(unique_vids)}')
    
    duplicates = df[df.duplicated(subset=['video_id', 'date'], keep=False)]
    num_duplicates = len(duplicates['video_id'])
    print(f'\nNumber of Duplicates Rows (with same id and same date): {num_duplicates}')
    
    print('\nDuplicate Videos and Counts:')
    print(duplicates[['video_id','date']].value_counts())
    
    print("\nAfter cleaning data...")
    
    df_clean = transform_df(df)
    print(f'\nOriginal Shape: {df.shape}')
    print(f'New Shape: {df_clean.shape}')
    print(f'Num rows dropped: {df.shape[0]-df_clean.shape[0]}')
    
    max_sim_score_stats = df_clean['max_score'].describe()
    print(f'\nAverage of Max Similartiy Stats:\n {max_sim_score_stats}')

# %%
filename = "cosine_sim_video_description_12345.csv"
data = load_data(filename)
explore_data(data)
# Out:
# Total Number of Rows: 158
# Number of Unique Videos: 131
#
# Number of Duplicates Rows (with same id and same date): 36
#
# Duplicate Videos and Counts:
# video_id             date
# 7326246871024930091  2024-01-20    4
# 7326271896960503072  2024-01-20    4
# 7332620181874773290  2024-02-06    4
# 7332721185731644718  2024-02-07    4
# 7333618266436406561  2024-02-09    4
# 7335453895377915141  2024-02-14    4
# 7337266783147101446  2024-02-19    4
# 7339620455587925254  2024-02-25    4
# 7339991777320979754  2024-02-26    4
# Name: count, dtype: int64
#
# After cleaning data...
#
# Original Shape: (158, 13)
# New Shape: (118, 13)
# Num rows dropped: 40
#
# Average of Max Similartiy Stats:
#  count    118.000000
# mean       0.376831
# std        0.123548
# min        0.149100
# 25%        0.290075
# 50%        0.353600
# 75%        0.447200
# max        0.730300
# Name: max_score, dtype: float64

# %%
df = transform_df(data)
df
# Out:
#      Unnamed: 0             video_id        date  \
# 157         157  7311197019974978858  2023-12-10
# 87           87  7339224135303728414  2024-02-24
# 78           78  7339228841287634209  2024-02-24
# 124         124  7339253671022087470  2024-02-24
# 141         141  7333675404965793054  2024-02-09
# ..          ...                  ...         ...
# 38           38  7337443453816573190  2024-02-19
# 86           86  7337822676783795499  2024-02-20
# 56           56  7339934638011452714  2024-02-26
# 59           59  7339913244435385646  2024-02-26
# 114         114  7339304215627517227  2024-02-24
#
#                                      video_description  \
# 157  A doubleheader in primetime 🤩 8:15 ET | Titans...
# 87   A sailing captain was paddle-boarding along th...
# 78   The woman who found the undetonated WW2 bomb i...
# 124  Part 30| Autistic murder suspect hallucinates ...
# 141  Arguably the darkest time during the slave era...
# ..                                                 ...
# 38   I can’t see this alone😂😭😭#naijatiktok #fyp #jo...
# 86   Korean man appeals his case #korea #news #crim...
# 56   Part 46| Detective completely outsmarts suspec...
# 59   Part 44| 15 year old Ellen blatantly lies abou...
# 114  [ Part 3] Husband Loses It After Discovering W...
#
#                                           similarities  \
# 157  [(0.7303, 'A 3-Year Odyssey in Pursuit of a Mo...
# 87   [(0.6717, 'Quotation of the Day: Yale Tackle I...
# 78   [(0.654, 'Quotation of the Day: Yale Tackle Is...
# 124  [(0.6455, 'Quotation of the Day: Yale Tackle I...
# 141  [(0.6325, 'When the Food Is Lovingly Prepared ...
# ..                                                 ...
# 38   [(0.189, 'How I Designed My Perfect Connection...
# 86   [(0.1826, 'A Love Song to His Roots'), (0.1414...
# 56   [(0.1826, 'Crime Scene'), (0.1557, 'Woman, 74,...
# 59   [(0.1826, 'Entrapment, Corruption, Murder and ...
# 114  [(0.1491, 'How the Subway’s Weekend Problem Fi...
#
#                                         cos_sim_scores  \
# 157  [0.7303, 0.6708, 0.4082, 0.3922, 0.3922, 0.378...
# 87   [0.6717, 0.552, 0.5102, 0.5056, 0.4823, 0.4769...
# 78   [0.654, 0.4968, 0.4968, 0.4644, 0.4625, 0.4596...
# 124  [0.6455, 0.5883, 0.5345, 0.4714, 0.4264, 0.408...
# 141  [0.6325, 0.6325, 0.6325, 0.6325, 0.6325, 0.516...
# ..                                                 ...
# 38   [0.189, 0.1667, 0.1667, 0.1667, 0.1581, 0.1508...
# 86   [0.1826, 0.1414, 0.1414, 0.1414, 0.1414, 0.134...
# 56   [0.1826, 0.1557, 0.1557, 0.1491, 0.1491, 0.143...
# 59   [0.1826, 0.1826, 0.1633, 0.1633, 0.1491, 0.143...
# 114  [0.1491, 0.1414, 0.1414, 0.1414, 0.1414, 0.129...
#
#                                          nyt_headlines  \
# 157  ['A 3-Year Odyssey in Pursuit of a Mountain My...
# 87   ['Quotation of the Day: Yale Tackle Isn’t the ...
# 78   ['Quotation of the Day: Yale Tackle Isn’t the ...
# 124  ['Quotation of the Day: Yale Tackle Isn’t the ...
# 141  ['When the Food Is Lovingly Prepared by the Ac...
# ..                                                 ...
# 38   ['How I Designed My Perfect Connections Solve'...
# 86   ['A Love Song to His Roots', '‘Beginning of th...
# 56   ['Crime Scene', 'Woman, 74, Killed by Falling ...
# 59   ['Entrapment, Corruption, Murder and Justice i...
# 114  ['How the Subway’s Weekend Problem Fixer Spend...
#
#                                       similarities_lst  \
# 157  [(0.7303, A 3-Year Odyssey in Pursuit of a Mou...
# 87   [(0.6717, Quotation of the Day: Yale Tackle Is...
# 78   [(0.654, Quotation of the Day: Yale Tackle Isn...
# 124  [(0.6455, Quotation of the Day: Yale Tackle Is...
# 141  [(0.6325, When the Food Is Lovingly Prepared b...
# ..                                                 ...
# 38   [(0.189, How I Designed My Perfect Connections...
# 86   [(0.1826, A Love Song to His Roots), (0.1414, ...
# 56   [(0.1826, Crime Scene), (0.1557, Woman, 74, Ki...
# 59   [(0.1826, Entrapment, Corruption, Murder and J...
# 114  [(0.1491, How the Subway’s Weekend Problem Fix...
#
#                                     cos_sim_scores_lst  \
# 157  [0.7303, 0.6708, 0.4082, 0.3922, 0.3922, 0.378...
# 87   [0.6717, 0.552, 0.5102, 0.5056, 0.4823, 0.4769...
# 78   [0.654, 0.4968, 0.4968, 0.4644, 0.4625, 0.4596...
# 124  [0.6455, 0.5883, 0.5345, 0.4714, 0.4264, 0.408...
# 141  [0.6325, 0.6325, 0.6325, 0.6325, 0.6325, 0.516...
# ..                                                 ...
# 38   [0.189, 0.1667, 0.1667, 0.1667, 0.1581, 0.1508...
# 86   [0.1826, 0.1414, 0.1414, 0.1414, 0.1414, 0.134...
# 56   [0.1826, 0.1557, 0.1557, 0.1491, 0.1491, 0.143...
# 59   [0.1826, 0.1826, 0.1633, 0.1633, 0.1491, 0.143...
# 114  [0.1491, 0.1414, 0.1414, 0.1414, 0.1414, 0.129...
#
#                                          headlines_lst   avg_sim  max_score  \
# 157  [A 3-Year Odyssey in Pursuit of a Mountain Mys...  0.123569     0.7303
# 87   [Quotation of the Day: Yale Tackle Isn’t the B...  0.179833     0.6717
# 78   [Quotation of the Day: Yale Tackle Isn’t the B...  0.152366     0.6540
# 124  [Quotation of the Day: Yale Tackle Isn’t the B...  0.149042     0.6455
# 141  [When the Food Is Lovingly Prepared by the Act...  0.117077     0.6325
# ..                                                 ...       ...        ...
# 38   [How I Designed My Perfect Connections Solve, ...  0.015648     0.1890
# 86   [A Love Song to His Roots, ‘Beginning of the E...  0.011748     0.1826
# 56   [Crime Scene, Woman, 74, Killed by Falling Bri...  0.004804     0.1826
# 59   [Entrapment, Corruption, Murder and Justice in...  0.005455     0.1826
# 114  [How the Subway’s Weekend Problem Fixer Spends...  0.015016     0.1491
#
#      num_headlines
# 157           4384
# 87            5176
# 78            5176
# 124           5176
# 141           9462
# ..             ...
# 38            4263
# 86            7644
# 56          222493
# 59          222493
# 114           5176
#
# [118 rows x 13 columns]

# %% [markdown]
# ## Visualize the Data

# %%
# Histogram of the maximum cosine similarity scores
def histogram(df,feature,xlab,title):
    hist = sns.histplot(df[feature])
    plt.title(title)
    plt.xlabel(xlab)
    plt.ylabel('Frequency')

# h = histogram(df, 'max_score','Maximum Cosine Similarity Score','Maximum Scores')

# %%
# Find top 5 videos with highest average scores
def get_top5(df, feature):
    top5 = df.iloc[:5]
    video_ids =[]
    for index, row in top5.iterrows():
        print("**********************************************************************")
        print(f"\nVideo ID: {row['video_id']}")
        video_ids.append(row['video_id'])
        print(f"\nVideo\'s {feature}: {row[feature]}")
        print(f"\nDate watched: {row['date']}")
        print(f"\nTop 5 similarities:")
        for sim in row['similarities_lst'][:5]:
            print(sim)
    return video_ids
            
# top5_video_ids = get_top5(df,'video_description')

# %%
# Cosine similarity functions
import numpy as np
from numpy.linalg import norm
import string

def getVocabulary(textchunk):
    """Given some text, create the vocabulary of unique words."""
    textchunk = textchunk.lower()
    cleantext = "".join(char for char in textchunk if char not in string.punctuation)
    words = set(cleantext.split())
    voc = sorted(words)
    return voc

def text2vector(sentence, voc):
    """Given a sentence and the vocabulary for the problem,
    turn every sentence into a vector.
    """
    cleantext = "".join(char for char in sentence if char not in string.punctuation)
    words = cleantext.lower().split()
    vector = [words.count(w) for w in voc]
    return vector

def cosineSimilarity(vec1, vec2):
    """Calculate the cosine similarity between two vectors."""
    V1 = np.array(vec1)
    V2 = np.array(vec2)
    cosine = np.dot(V1, V2)/(norm(V1)*norm(V2))
    return cosine

# %%
# Create a heatmap of the cosine similarities 
# between the top n news headlines
def drawHeatmap(sentLabels, simMtrx, plotTitle):
    """Draws a heatmap for the similarity matrix.
    """
    sns.set(font_scale=0.9)
    g = sns.heatmap(
          simMtrx, # similarity matrix with the cosine sim values
          xticklabels=sentLabels,
          yticklabels=sentLabels,
          vmin=0,
          vmax=1,
          cmap="YlOrRd")
    g.set_xticklabels(sentLabels, rotation=90)
    g.set_title(plotTitle, fontsize=14)
    plt.show()
    
def get_top_n_headlines(df,video_id,n,feature):
    # Get the top n headlines for video
    video = df[df['video_id']==video_id].iloc[0]
    feature_text = video[feature]
    top_n_similarities = video['similarities_lst'][:n]
    top_n_headlines = video['headlines_lst'][:n]
    
    # Create vocabulary for all headlines
    all_headlines_str = " ".join(top_n_headlines)
    voc = getVocabulary(all_headlines_str)
    
    # Convert sentences to vectors
    headline_vecs = [text2vector(headline, voc) for headline in top_n_headlines]
    
    sim_matrix = []
    for vec1 in headline_vecs:
        sim_row = []
        for vec2 in headline_vecs:
            sim_row.append(cosineSimilarity(vec1, vec2))
        sim_matrix.append(sim_row)
    
    return sim_matrix, top_n_headlines,feature_text, top_n_similarities


# video_id =7338586099721309471
# feature = "video_description"
# n = 10
# sim_matrix, top_n_headlines,feature_text,top_n_similarities = get_top_n_headlines(df,video_id,n,feature)
# headline_labs = [headline[:20] for headline in top_n_headlines]
# title = f'Cosine Similarities Between Top {n} Most Similar Headlines'
# print(feature_text)
# for sim in top_n_similarities:
#     print(sim)
# drawHeatmap(headline_labs,sim_matrix,title)

# %%
def drawHistogramForVideo(video_id, df, feature, xlab,title):
    video = df[df['video_id']==video_id].iloc[0]
    dataToPlot = video[feature]
    hist = sns.histplot(dataToPlot)
    plt.title(title)
    plt.xlabel(xlab)
    plt.ylabel('Frequency')
    plt.show()

# video_id = 7311197019974978858
# feature = "cos_sim_scores_lst"
# xlab = "Cosine Similarity Scores"
# title = f"Distribution of Cosine Similarity Scores for Video {video_id}"
# drawHistogramForVideo(video_id, df, feature, xlab,title)

# %% [markdown]
# ## Function to Explore and Analyze

# %%
def complete_analysis(filename,feature, code):
    print("\n*****EXPLORE THE DATA*****")
    data = load_data(filename)
    explore_data(data)
    df = transform_df(data)
    title = f'Distribution of Maximum Similarity Scores for User {code}'
    h = histogram(df, 'max_score','Maximum Cosine Similarity Score',title)
    plt.show(h)
    
    print("\n*****TOP 5 ANALYSIS*****")
    top5_video_ids = get_top5(df,'video_description')
    
    print("\n*****HISTOGRAMS OF VIDEOS THAT HAVE HIGHEST SCORES*****")
    for video_id in top5_video_ids:
        feature = "cos_sim_scores_lst"
        xlab = "Cosine Similarity Scores"
        title = f"Distribution of Cosine Similarity Scores for Video {video_id}"
        h2 = drawHistogramForVideo(video_id, df, feature, xlab,title)
        plt.show(h2)
    
#     print("\n*****HEATMAPS COMPARING MOST SIMILAR HEADLINES*****")
#     for vid_id in top5_video_ids:
#         feature = "video_description"
#         n = 10
#         sim_matrix, top_n_headlines,feature_text, top_n_similarities = get_top_n_headlines(df,vid_id,n,feature)
#         headline_labs = [headline[:20] for headline in top_n_headlines]
#         title = f'Cosine Similarities Between Top {n} Most Similar Headlines'
#         print(feature_text)
#         for sim in top_n_similarities:
#             print(sim)
#         drawHeatmap(headline_labs,sim_matrix,title)

# %% [markdown]
# ## ACCOUNT 12345

# %%
code = 12345
filename = "cosine_sim_video_description_12345.csv"
feature = "video_description"

complete_analysis(filename,feature,code)
# Out:
# *****EXPLORE THE DATA*****
# Total Number of Rows: 158
# Number of Unique Videos: 131
#
# Number of Duplicates Rows (with same id and same date): 36
#
# Duplicate Videos and Counts:
# video_id             date
# 7326246871024930091  2024-01-20    4
# 7326271896960503072  2024-01-20    4
# 7332620181874773290  2024-02-06    4
# 7332721185731644718  2024-02-07    4
# 7333618266436406561  2024-02-09    4
# 7335453895377915141  2024-02-14    4
# 7337266783147101446  2024-02-19    4
# 7339620455587925254  2024-02-25    4
# 7339991777320979754  2024-02-26    4
# Name: count, dtype: int64
#
# After cleaning data...
#
# Original Shape: (158, 13)
# New Shape: (118, 13)
# Num rows dropped: 40
#
# Average of Max Similartiy Stats:
#  count    118.000000
# mean       0.376831
# std        0.123548
# min        0.149100
# 25%        0.290075
# 50%        0.353600
# 75%        0.447200
# max        0.730300
# Name: max_score, dtype: float64
# *****TOP 5 ANALYSIS*****
# **********************************************************************
#
# Video ID: 7311197019974978858
#
# Video's video_description: A doubleheader in primetime 🤩 8:15 ET | Titans-Dolphins ESPN/ESPN+ | Packers-Giants ABC/ESPN+ #nfl #football #titans #dolphins #packers #giants
#
# Date watched: 2023-12-10
#
# Top 5 similarities:
# (0.7303, 'A 3-Year Odyssey in Pursuit of a Mountain Mystery in Argentina')
# (0.6708, 'Chicken on Bread in Sauce in a Skillet')
# (0.4082, 'Days After Heated Debate, G.O.P. Candidates Take a Gentler Tone in Iowa')
# (0.3922, 'Who’s a ‘Colonizer’? How an Old Word Became a New Weapon')
# (0.3922, 'In ‘Airplane Mode,’ Not All Travelers Head in the Same Direction')
# **********************************************************************
#
# Video ID: 7339224135303728414
#
#
# Date watched: 2024-02-24
#
# Top 5 similarities:
# (0.654, 'Quotation of the Day: Yale Tackle Isn’t the Best in the Draft, but Might Be the Most ‘Interesting’')
# (0.4968, 'Trump is the overwhelming front-runner in South Carolina. Here’s the latest.')
# (0.4968, 'Results: The Most Detailed Maps of the South Carolina Republican Primary')
# (0.4644, 'What to Watch in the South Carolina G.O.P. Primary')
# (0.4625, '35 Hours for a 10-Second Clip: The Art of the TikTok Trick Shot')
# **********************************************************************
#
# Video ID: 7339253671022087470
#
# Video's video_description: Part 30| Autistic murder suspect hallucinates in the interrogation room | CREDIT: @EWU CREW #interrogation #interview #interrogationroom #murder #crime #truecrime #crimestories
#
# Date watched: 2024-02-24
#
# Top 5 similarities:
# (0.6455, 'Quotation of the Day: Yale Tackle Isn’t the Best in the Draft, but Might Be the Most ‘Interesting’')
# (0.5883, 'Trump is the overwhelming front-runner in South Carolina. Here’s the latest.')
# (0.5345, 'The Cost of Nuclear War in Space')
# (0.4714, 'What to Watch in the South Carolina G.O.P. Primary')
# (0.4264, 'Police in Kentucky Arrest Man in University Student’s Killing')
# **********************************************************************
#
# Video ID: 7333675404965793054
#
# Video's video_description: Arguably the darkest time during the slave era. #✊🏾✊🏾✊🏾 #blackhistorymonth #dismantlethesystem #systemicracism #Community #BHM #blackcommunitytiktok #blacklivesmatter #Deconstruction #🍉🍉🍉
#
# Date watched: 2024-02-09
#
# Top 5 similarities:
# (0.6325, 'When the Food Is Lovingly Prepared by the Actors (and the Chef)')
# (0.6325, 'The Year of the Dragon Plant')
# (0.6325, 'The Weekender')
# (0.6325, 'Is the Senate Becoming the House?')
# (0.6325, 'Aboard the Icon of the Seas')
#
# *****HISTOGRAMS OF VIDEOS THAT HAVE HIGHEST SCORES*****

# %% [markdown]
# ## ACCOUNT 10824

# %%
code = 10824
filename = "cosine_sim_video_description_10824.csv"
feature = "video_description"

complete_analysis(filename,feature,code)
# Out:
# *****EXPLORE THE DATA*****
# Total Number of Rows: 158
# Number of Unique Videos: 131
#
# Number of Duplicates Rows (with same id and same date): 36
#
# Duplicate Videos and Counts:
# video_id             date
# 7326246871024930091  2024-01-20    4
# 7326271896960503072  2024-01-20    4
# 7332620181874773290  2024-02-06    4
# 7332721185731644718  2024-02-07    4
# 7333618266436406561  2024-02-09    4
# 7335453895377915141  2024-02-14    4
# 7337266783147101446  2024-02-19    4
# 7339620455587925254  2024-02-25    4
# 7339991777320979754  2024-02-26    4
# Name: count, dtype: int64
#
# After cleaning data...
#
# Original Shape: (158, 13)
# New Shape: (118, 13)
# Num rows dropped: 40
#
# Average of Max Similartiy Stats:
#  count    118.000000
# mean       0.376831
# std        0.123548
# min        0.149100
# 25%        0.290075
# 50%        0.353600
# 75%        0.447200
# max        0.730300
# Name: max_score, dtype: float64
# *****TOP 5 ANALYSIS*****
# **********************************************************************
#
# Video ID: 7311197019974978858
#
# Video's video_description: A doubleheader in primetime 🤩 8:15 ET | Titans-Dolphins ESPN/ESPN+ | Packers-Giants ABC/ESPN+ #nfl #football #titans #dolphins #packers #giants
#
# (0.552, '35 Hours for a 10-Second Clip: The Art of the TikTok Trick Shot')
# (0.5102, 'Trump is the overwhelming front-runner in South Carolina. Here’s the latest.')
# (0.5056, 'Results: The Most Detailed Maps of the South Carolina Republican Primary')
# (0.4823, 'The Cost of Nuclear War in Space')
# **********************************************************************
#
# Video ID: 7339228841287634209
#
# Video's video_description: The woman who found the undetonated WW2 bomb in her back garden has described the situation as an ‘absolute nightmare’. Natalie Jary said she wanted to say ‘sorry’ to the community and that it was like the last thing she thought could happen building an extension. The bomb forced thousands to leave the Keyham area of Plymouth in what was called one of the largest UK peacetime evacuation operations’. #plymouth #plymouthbomb #plymouthnews #ww2bomb #uknews #news #keyhambomb #undetonated #news #plymouthnews #fyp #newsfyp #newstok #tok #viralnews #trendingnews
#
# Date watched: 2024-02-24
#
# Top 5 similarities:
# (0.654, 'Quotation of the Day: Yale Tackle Isn’t the Best in the Draft, but Might Be the Most ‘Interesting’')
# (0.4968, 'Trump is the overwhelming front-runner in South Carolina. Here’s the latest.')
# (0.4968, 'Results: The Most Detailed Maps of the South Carolina Republican Primary')
# (0.4644, 'What to Watch in the South Carolina G.O.P. Primary')
# (0.4625, '35 Hours for a 10-Second Clip: The Art of the TikTok Trick Shot')
# **********************************************************************
#
# Video ID: 7339253671022087470
#
# Video's video_description: Part 30| Autistic murder suspect hallucinates in the interrogation room | CREDIT: @EWU CREW #interrogation #interview #interrogationroom #murder #crime #truecrime #crimestories
#
# Date watched: 2024-02-24
#
# Top 5 similarities:
# (0.6455, 'Quotation of the Day: Yale Tackle Isn’t the Best in the Draft, but Might Be the Most ‘Interesting’')
# (0.5883, 'Trump is the overwhelming front-runner in South Carolina. Here’s the latest.')
# (0.5345, 'The Cost of Nuclear War in Space')
# (0.4714, 'What to Watch in the South Carolina G.O.P. Primary')
# (0.4264, 'Police in Kentucky Arrest Man in University Student’s Killing')
# **********************************************************************
#
# Video ID: 7333675404965793054
#
# Video's video_description: Arguably the darkest time during the slave era. #✊🏾✊🏾✊🏾 #blackhistorymonth #dismantlethesystem #systemicracism #Community #BHM #blackcommunitytiktok #blacklivesmatter #Deconstruction #🍉🍉🍉
#
# Date watched: 2024-02-09
#
# Top 5 similarities:
# (0.6325, 'When the Food Is Lovingly Prepared by the Actors (and the Chef)')
# (0.6325, 'The Year of the Dragon Plant')
# (0.6325, 'The Weekender')
# (0.6325, 'Is the Senate Becoming the House?')
# (0.6325, 'Aboard the Icon of the Seas')
#
# *****HISTOGRAMS OF VIDEOS THAT HAVE HIGHEST SCORES*****

# %% [markdown]
# ## ACCOUNT 50405

# %%
code = 50405
filename = "cosine_sim_video_description_50405.csv"
feature = "video_description"

complete_analysis(filename,feature,code)
# Out:
# *****EXPLORE THE DATA*****
# Total Number of Rows: 111
# Number of Unique Videos: 111
#
# Number of Duplicates Rows (with same id and same date): 0
#
# Duplicate Videos and Counts:
# Series([], Name: count, dtype: int64)
#
# After cleaning data...
#
# Original Shape: (111, 13)
# New Shape: (85, 13)
# Num rows dropped: 26
#
# Average of Max Similartiy Stats:
#  count    85.000000
# mean      0.378072
# std       0.115432
# min       0.154300
# 25%       0.301500
# 50%       0.369800
# 75%       0.447200
# max       0.774600
# Name: max_score, dtype: float64
# *****TOP 5 ANALYSIS*****
# **********************************************************************
#
# Video ID: 7317864696747642158
#
# Video's video_description: Ladies get yourself a sports betting boyfriend #sportsbetting #boyfriend #sports #bet #cartier #christmas #christmaspresent #love #loveyou #sportsbettingtiktok
#
# Date watched: 2023-12-28
#
# Top 5 similarities:
# (0.7746, 'A Mother, a Daughter, a Deadly Journey: An Update')
# (0.378, 'Classic Wedding Traditions Find a New Groove')
# (0.378, 'A Hopeful Reminder: You’re Going to Die')
# (0.3536, 'When Being a Spokeswoman Attracts Leering Internet Trolls')
# (0.3536, 'A Holiday Celebration Inspired by Old New York')
# **********************************************************************
#
# Video ID: 7320325173209517317
#
# Video's video_description: Link in the comments #fyp #foryou #news #update #tiktok #booktok #greenscreen
#
# Date watched: 2024-01-04
#
# Top 5 similarities:
# (0.7071, 'The Fight Over D.E.I. in the C-suite')
# (0.5303, '‘Society of the Snow’ Review: The Stranded and the Faithful')
# (0.5, 'Homes for Sale in Manhattan and the Bronx')
# (0.4714, 'Crisis in the Red Sea, and Epstein Files Unsealed')
# (0.4472, 'Why Are So Many More Pedestrians Dying in the U.S.?')
# **********************************************************************
#
# Video ID: 7321085855760649515
#
# Video's video_description: The world isnt what it was when you were starting out, instead of dogging us for not wanting to work our lives away, take your position and experience to make a change for a better life for your children. You’ve had 20 years to experience life and in that time have also completely obliterated any chance for us to even start to have one.  - - - And maybe i just work at walmart, but i should still be able to pay my bills with a full time job. - - - - #fyp #foryou #trend #viral #news #genz #9to5
#
# Date watched: 2024-01-06
#
# Top 5 similarities:
# (0.5826, 'I Was Addicted to My Smartphone, So I Switched to a Flip Phone for a Month')
# (0.3904, 'How to Make the Most of a Home Inspection')
# (0.3578, 'What Happens When a Woman Wronged Resorts to Violence?')
# (0.3416, 'Back to (Better) Basics')
# (0.3237, 'Quotation of the Day: A Stroke Stole Manuel’s Ability to Communicate')
# **********************************************************************
#
# Video ID: 7318529459773066526
#
# Video's video_description: The worst comment section ever #holocaust #shoah #auschwitz #stopantisemitism #amyisraelchai #holocausteduction #learnontiktok
#
# Date watched: 2023-12-30
#
# Top 5 similarities:
# (0.5774, 'The Connections Companion')
# (0.5345, '11 Charts That Explain the Year in Business, Technology and the Economy')
# (0.4472, 'Where Was the Israeli Military?')
# (0.4472, 'The Statue of Liberty Hat')
# (0.4472, 'A ‘Holopoem’ for the Cosmos')
# **********************************************************************
#
# Video ID: 7324444161283804459
#
# Video's video_description: Im so upset. I cant even justify going to #tacobell anymore. #inflation
#
# Date watched: 2024-01-15
#
# Top 5 similarities:
# (0.5774, 'A Big Reason to Pay Attention to Iowa? New Hampshire.')
# (0.5164, '‘Not Where We Need to Be’: Boeing to Make Changes in Quality Control')
# (0.4472, '‘The Run-Up’ Guide to Iowa')
# (0.378, 'Is the Fed Falling Prey to Groupthink?')
# (0.3333, 'What to Watch For in the 2024 Iowa Caucuses')
#
# *****HISTOGRAMS OF VIDEOS THAT HAVE HIGHEST SCORES*****
